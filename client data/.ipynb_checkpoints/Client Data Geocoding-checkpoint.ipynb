# %%
import pandas as pd

#import sys
#sys.path.append(r"C:\Users\david\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\geocoder")
#import geocoder

# %%
rawData = pd.read_csv('des_moines_client 2018 2019.csv', encoding = "ISO-8859-1", header = 0)

fullAddress = []

for client in rawData:
    fullAddress.append(rawData['address'] + ' ' + rawData['City'] + ' ' + rawData['state'] + ' ' + rawData['Zipcode'].astype(str))
    #fullAddress = rawData['address'] + ' ' + rawData['City'] + ' ' + rawData['state'] + ' ' + rawData['Zipcode'].astype(str)
    #clean[client] = fullAddress

#print(fullAddress)


addressDf = pd.DataFrame(data = fullAddress)

addressDf.head()
# Out:
#                                   0                                    1     \
# 0  20813 32ND LANE S SEATAC wa 98198.0  20813 32ND LANE S SEATAC wa 98198.0
# 1  20813 32ND LANE S SEATAC wa 98198.0  20813 32ND LANE S SEATAC wa 98198.0
# 2  20813 32ND LANE S SEATAC wa 98198.0  20813 32ND LANE S SEATAC wa 98198.0
# 3  20813 32ND LANE S SEATAC wa 98198.0  20813 32ND LANE S SEATAC wa 98198.0
# 4  20813 32ND LANE S SEATAC wa 98198.0  20813 32ND LANE S SEATAC wa 98198.0
#
#                                   2                                      3     \
# 0  20813 32ND LANE S SEATAC wa 98198.0  21833 7TH AVE S DES MOINES wa 98198.0
# 1  20813 32ND LANE S SEATAC wa 98198.0  21833 7TH AVE S DES MOINES wa 98198.0
# 2  20813 32ND LANE S SEATAC wa 98198.0  21833 7TH AVE S DES MOINES wa 98198.0
# 3  20813 32ND LANE S SEATAC wa 98198.0  21833 7TH AVE S DES MOINES wa 98198.0
# 4  20813 32ND LANE S SEATAC wa 98198.0  21833 7TH AVE S DES MOINES wa 98198.0
#
# ...
