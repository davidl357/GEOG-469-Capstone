# %%
import pandas as pd

import sys
sys.path.append(r"C:\Users\david\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\geocoder")
import geocoder

rawData.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-83f907927426> in <module>()
#       3 import sys
#       4 sys.path.append(r"C:\Users\david\AppData\Local\Programs\Python\Python36-32\Lib\site-packages\geocoder")
# ----> 5 import geocoder
#       6
#       7 rawData.head()
#
# ModuleNotFoundError: No module named 'geocoder'

# %%
rawData = pd.read_csv('des_moines_client.csv', encoding = "ISO-8859-1", header = 0)

for client in rawData:

    print(rawData['address'] + ' ' + rawData['City'] + ' ' + rawData['state'])
# Out:
# 0                            10031 SE 258TH PL KENT wa
# 1                        1006 S 206TH ST DES MOINES wa
# 2            1011 S KENT DES MOINES ROAD DES MOINES wa
# 3            1011 S KENT DES MOINES ROAD DES MOINES wa
# 4                            1014 37TH ST SE AUBURN wa
# 5                            1014 37TH ST SE AUBURN wa
# 6                            1014 37TH ST SE AUBURN wa
# 7                            1014 37TH ST SE AUBURN wa
# 8                     1019 S W 306TH ST FEDERAL WAY wa
# 9                     1019 S W 306TH ST FEDERAL WAY wa
# 10                    1019 S W 306TH ST FEDERAL WAY wa
# 11                              102 SUMMIT AVE KENT wa
# 12                       1020 S 230TH ST DES MOINES wa
# 13                       1020 S 230TH ST DES MOINES wa
# 14                       1022 S 230TH ST DES MOINES wa
# 15                       1032 S 250TH ST DES MOINES wa
# 16                       1037 S 194TH ST DES MOINES wa
# ...

# %%
print(rawData)
# Out:
#       MemberID                    Address Apt Nbr.        City  Zipcode  HHID  \
# 0         1266            1357 S 279TH ST      NaN  DES MOINES  98198.0   381
# 1         1265            1357 S 279TH ST      NaN  DES MOINES  98198.0   381
# 2         1268            1357 S 279TH ST      NaN  DES MOINES  98198.0   381
# 3         2335           21930 29TH AVE S        B  DES MOINES  98198.0   712
# 4         2334           21930 29TH AVE S        B  DES MOINES  98198.0   712
# 5         2374            2005 S 241ST ST      NaN  DES MOINES  98198.0   724
# 6         2377            2005 S 241ST ST      NaN  DES MOINES  98198.0   724
# 7         2376            2005 S 241ST ST      NaN  DES MOINES  98198.0   724
# 8         2871            1135 S 211TH PL      NaN  DES MOINES  98198.0   857
# 9         2870            1135 S 211TH PL      NaN  DES MOINES  98198.0   857
# 10        4183            1739 S 234TH DR      NaN  DES MOINES  98198.0  1229
# ...
